# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_path = "runs/sac/CheetahRun/main_viz/seed-000-2026-06-15-19-28-11/progress.csv"

# %%
df = pd.read_csv(file_path)

# %%
plt.plot(df["Train/Steps"], df["Analysis/Val_diff"], label="val_diff")
plt.plot(df["Train/Steps"], df["Analysis/SA_diff"], label="sa_diff")

plt.xlabel("Steps")
plt.ylabel("Return")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
